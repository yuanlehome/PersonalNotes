# %%
import matplotlib.pyplot as plt
import csv

def read_csv(input_file):
  with open(input_file, "r") as f:
      reader = csv.reader(f, delimiter=" ")
      res = []
      for data in reader:
        res.append(data)
      return res

x = [114.39, 2911.62, 4288.53, 5611.47, 8701.89]
y = [14622, 11940, 10022, 8100, 3876]

x2 = [186.45, 2963.28, 4292.95, 5573.55, 8753.28]
y2 = [30670, 27990, 26070, 24150, 19922]
plt.plot(x,y,"r:o")
plt.plot(x2,y2,"r:o")

plt.xlabel("ms")
plt.ylabel("MiB")
plt.annotate('bs=1', xy=(2500, 9000))
plt.annotate('bs=32', xy=(2500, 25000))
plt.title("GPT-2 6.7B")
plt.show()

# %%
import matplotlib.pyplot as plt
import csv

def read_csv(input_file):
  with open(input_file, "r") as f:
      reader = csv.reader(f, delimiter=" ")
      res = []
      for data in reader:
        res.append(data)
      return res

x = [580.36, 2954.24, 4271.91, 5587.98, 8482.84]
y = [14061, 11379, 9459, 7537, 3313]

x2 = [8482.84, 8531.39, 8581.78, 8514.83]
y2 = [3313, 6935, 11083, 14715]
plt.plot(x,y,"r:o")
plt.plot(x2,y2,"y:o")

plt.xlabel("ms")
plt.ylabel("MiB")
plt.annotate('bs=1', xy=(2500, 9000))
plt.annotate('bs=8', xy=(8000, 7000))
plt.annotate('bs=16', xy=(8000, 11000))
plt.annotate('bs=23', xy=(8000, 15000))
plt.title("T4 GPT-2 6.7B")
plt.show()

# %%
import matplotlib.pyplot as plt
import csv

def read_csv(input_file):
  with open(input_file, "r") as f:
      reader = csv.reader(f, delimiter=" ")
      res = []
      for data in reader:
        res.append(data)
      return res

x = [580.36, 2954.24, 4271.91, 5587.98, 8482.84]
y = [14061, 11379, 9459, 7537, 3313]

x2 = [400.88, 3046.63, 4191.93, 5340.89, 7410.4]
y2 = [13915, 9691, 7771, 5849, 2393]
plt.plot(x,y,"r:o")
plt.plot(x2,y2,"y:o")

plt.xlabel("ms")
plt.ylabel("MiB")
plt.annotate('OpenBMB inference', xy=(2200, 8000))
plt.annotate('Paddle inference', xy=(4000, 9000))
plt.title("T4 GPT-2 6.7B BS=1")
plt.show()
